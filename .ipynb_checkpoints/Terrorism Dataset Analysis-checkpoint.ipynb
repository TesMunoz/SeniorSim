# %% [markdown]
# # Global Terrorism DataSet Analysis:
#
# Data:
#     - Where from?
#     - Items
#     - Scope
#     - Contributors
#
# Goals:
#     - ...

# %%
import pandas as pd
from pandas.plotting import scatter_matrix

import numpy as np

import matplotlib.pyplot as plt
import matplotlib.collections as mcol
#use this style of plots
plt.style.use('ggplot') 
#print plots in notebook
# %matplotlib inline 

import sklearn as sk
from sklearn.cluster import *
from sklearn.preprocessing import OneHotEncoder

# %%
def convert_eventid_to_datetime(df, ignore_bad_data=True):
    """Converts dataframe with event_id column to date time formats. Returns new DF with additional 'datetime' column."""
    from datetime import datetime
    
    datetime_series = []
    ix_to_drop = []
    count = 0
    for i, row in df.iterrows():
        try:
            year = int(row['iyear'])
            month = int(row['imonth'])
            day = int(row['iday'])
            datetime_series.append( datetime(year, month, day) )
        except:
            ix_to_drop.append(count)
            if not ignore_bad_data:
                print("Bad Event ID date format: {}, {}, {}. Event ID: {}"
                      .format(year, month, day, row['eventid']) )
                raise ValueError('Event Id data contains bad dates.')
        count += 1
        
    print('Dropped {} malformed event id rows out of {}.'.format(len(ix_to_drop), df.shape[0]))
    df = df.drop(df.index[ix_to_drop])
    df['datetime'] = pd.to_datetime(datetime_series)
    
    return df

# %% [markdown]
# ## Read in and sub-sample data
#
# 1. Read in dataframe, specifying subset of columns
# 2. Optionally sub-sample data to manageable size

# %%
#read in the data file and make into a pandas dataframe: location, only specific columns
original_df = pd.read_csv('./inputs/globalterrorismdb.csv', encoding='ISO-8859-1', usecols=['eventid', 'iyear', 'imonth', 'iday', 'country', 'region', 
                         'latitude', 'longitude', 'crit1', 'crit2', 'crit3', 'attacktype1','targtype1','targsubtype1','weaptype1',
                          'weapsubtype1'],
                         dtype={'iyear':'int', 'imonth':'int', 'iday':'int'});

#use a manageable sample size
num_rows = 2000
#shows the size of the original data
# print('Original shape of CSV: {}'.format(original_df.shape))

# DropNA() is dropping all NaN values from the dataset. Talk about potential bias. Investigate what causes this bad data.
#Free up memory by deleting the unused origial data
terrorism_df = original_df.dropna().sample(n=num_rows)
del original_df
print(type(terrorism_df))

#displays the columns being used
print(terrorism_df.columns)

# Convert known event times to timestamp column
datetime_df = convert_eventid_to_datetime(terrorism_df, ignore_bad_data=True)    
print(datetime_df.shape)

terrorism_df = datetime_df
del datetime_df

terrorism_df.head
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index(['eventid', 'iyear', 'imonth', 'iday', 'country', 'region', 'latitude',
#        'longitude', 'crit1', 'crit2', 'crit3', 'attacktype1', 'targtype1',
#        'targsubtype1', 'weaptype1', 'weapsubtype1'],
#       dtype='object')
# Dropped 6 malformed event id rows out of 2000.
# (1994, 17)
# <bound method NDFrame.head of              eventid  iyear  imonth  iday  country  region   latitude  \
# 41113   199001130004   1990       1    13       43       3 -33.469115
# 57766   199411250002   1994      11    25      183      11 -26.177929
# 155766  201511300053   2015      11    30      160       5   9.971311
# 7459    197902030008   1979       2     3      185       8  43.220480
# 65076   199704110006   1997       4    11      235       9  44.818611
# 24022   198501020002   1985       1     2      159       3  -6.774056
# 130330  201404170065   2014       4    17      147      11   5.518988
# 43839   199009070009   1990       9     7        8      11  -9.251797
# 81296   200608270002   2006       8    27       95      10  33.851043
# 12311   198011250005   1980      11    25       61       2  13.888888
# 127146  201402150015   2014       2    15      208      10  36.560394
# 134621  201407120076   2014       7    12       97      10  32.084465
# 19228           6          16.0 1983-07-15
# 23281           6          16.0 1984-09-26
# 20393           6          16.0 1983-12-13
# ...           ...           ...        ...
# 136761          6           8.0 2014-08-24
# 122436          5           5.0 2013-10-25
# 99197           6          17.0 2010-11-30
# 39941           6          16.0 1989-10-05
# 14577           6          16.0 1981-10-25
# 162864          6          16.0 2016-06-04
# 125378          5           5.0 2014-01-05
# 54836           6          16.0 1994-01-19
# 132379          5           5.0 2014-05-28
# 103956          5           5.0 2011-11-17
# 43601           6          16.0 1990-08-14
# 154006          6           8.0 2015-10-17
# 77269           6          11.0 2005-01-02
# 59097           9          21.0 1995-05-15
# 24258           5           2.0 1985-02-05
# 142399          5           5.0 2015-01-09
# 133718          6          16.0 2014-06-25
# 142691          6          16.0 2015-01-15
# 152605          8          18.0 2015-09-10
# 71582           6          16.0 2001-01-02
# 103444          6          13.0 2011-10-24
# 805             6          16.0 1971-04-06
# 131808          6          16.0 2014-05-18
# 48032           6          16.0 1991-09-15
# 159701          5           5.0 2016-03-14
# 57161           6          16.0 1994-09-10
# 132682          6          16.0 2014-06-03
# 84329           6          16.0 2007-10-12
# 26501           6          16.0 1985-11-05
# 139640          6          11.0 2014-11-01
#
# [1994 rows x 17 columns]>

# %% [markdown]
# ## Scatter Plots
# Can see how some of the data may be realted based on scatter plots generated:
#     1. Latitude vs Longitude shows us the location of attacks.
#         *Could underlay a map to get a better visual if wanted.

# %%
# terrorism_df['iyear']
# print(terrorism_df.shape)
# print(terrorism_df.columns)

year_lat_df = terrorism_df[0:100][['latitude', 'longitude']]

year_lat_df.plot.scatter(x='longitude',y='latitude')

# %% [markdown]
# ### Testing clustering on Latitude and Longitude
#       1. Use K-means algorthim to cluster points to two groups based on "closeness"
#       2. Use colormap to view the different clusters

# %%
from sklearn.cluster import KMeans

cl = sk.cluster.KMeans(n_clusters=2).fit(year_lat_df)

year_lat_df.plot.scatter(x='latitude',y='longitude', c=cl.labels_, colormap='viridis')

# %% [markdown]
# ### One hot encoding
#
# One hot encoding deals with our categorical variables by creating an <em>n-dimensional</em> row vector per category.
#
# * Specify columns
# * Get dummy variables
#     * Optionally append to previous dataframe

# %%
#create new data frame with the dummy variables included
t_dummies_df = pd.get_dummies(terrorism_df, columns=['weaptype1', 'region'], dtype=bool)


t_dummies_df.iloc[0:10]
# Out:
#              eventid  iyear  imonth  iday  country   latitude  longitude  \
# 72475   200108050009   2001       8     5       97  32.085305  34.785769
# 78426   200507160007   2005       7    16       95  33.411707  44.432341
# 87047   200806010003   2008       6     1       95  33.750000  44.633333
# 47194   199107160027   1991       7    16       50  45.338317  16.090980
# 133598  201406220075   2014       6    22       92  18.809919  82.720464
# 69342   199909120001   1999       9    12       59  -0.145228 -76.271083
# 107488  201205080003   2012       5     8        4  32.861513  69.126826
# 53597   199210280008   1992      10    28       43 -33.469115 -70.641997
# 76637   200407030007   2004       7     3        6  37.001385   6.554320
# 163922  201607010022   2016       7     1       95  33.664211  44.373761
#
#         crit1  crit2  crit3    ...      region_3  region_4  region_5  \
# 72475       1      1      1    ...         False     False     False
# 78426       1      1      0    ...         False     False     False
# 87047       1      1      1    ...         False     False     False
# 47194       1      1      1    ...         False     False     False
# 133598      1      1      1    ...         False     False     False
# 69342       1      1      1    ...          True     False     False
# 107488      1      1      1    ...         False     False     False
# 53597       1      1      1    ...          True     False     False
# 76637       1      1      0    ...         False     False     False
# 163922      1      1      1    ...         False     False     False
#
#         region_6  region_7  region_8  region_9  region_10  region_11  \
# 72475      False     False     False     False       True      False
# 78426      False     False     False     False       True      False
# 87047      False     False     False     False       True      False
# 47194      False     False     False      True      False      False
# 133598      True     False     False     False      False      False
# 69342      False     False     False     False      False      False
# 107488      True     False     False     False      False      False
# 53597      False     False     False     False      False      False
# 76637      False     False     False     False       True      False
# 163922     False     False     False     False       True      False
#
#         region_12
# 72475       False
# 78426       False
# 87047       False
# 47194       False
# 133598      False
# 69342       False
# 107488      False
# 53597       False
# 76637       False
# 163922      False
#
# [10 rows x 31 columns]

# %% [markdown]
# ### Pair Plots

# %%
#Plots each variable with each other and displays a matrix of different plots
scatter_matrix(terrorism_df[['iyear', 'latitude', 'longitude']], figsize=(12, 12))
plt.show()

# %% [markdown]
# # Data Exploration
#     Questions:
#         1. Is there a certain time during the year that attacks are more frequent?

# %% [markdown]
# ### Subsection 1: Time of Year

# %%
#Create a encoding that makes true/false columns for each month
months_region_dummies_df = pd.get_dummies(terrorism_df, columns=['region'], dtype=bool)

months_region_dummies_df.iloc[0:10]

#make a new dataframe based on region 10:
region_10_df = months_region_dummies_df[(months_region_dummies_df['region_10'] == 1)]
# region_10_df.iloc[0:10]

#Plot 

#scatter_matrix(region_10_df[['iyear', 'iday', 'imonth']], figsize=(12, 12))
#plt.show()

#dates_region_df = region_10_df[0:100][['iyear','iday']]
# dates_region_df.plot.scatter(x='iyear',y='iday')

# cl = sk.cluster.KMeans(n_clusters=2).fit(dates_region_df)

# dates_region_df.plot.scatter(x='iyear',y='iday', c=cl.labels_, colormap='viridis')

# region_10_df['iday'].hist(histtype='step')


# def convert_eventid_to_datetime(df, ignore_bad_data=True):
#     """Converts dataframe with event_id column to date time formats. Returns new DF with additional 'datetime' column."""
#     from datetime import datetime
#     datetime_series = []
#     ix_to_drop = []
#     count = 0
#     for i, row in df.iterrows():
#         try:
#             datetime_series.append( datetime(row['iyear'], row['imonth'], row['iday']) )
#         except:
#             ix_to_drop.append(count)
#             if not ignore_bad_data:
#                 print("Bad Event ID date format: {}, {}, {}. Event ID: {}"
#                       .format(row['iyear'], row['imonth'], int(row['iday']), row['eventid']) )
#                 raise ValueError('Event Id data contains bad dates.')
#         count += 1
        
#     print('Dropped {} malformed event id rows.'.format(len(ix_to_drop)))
#     df = df.drop(df.index[ix_to_drop])
#     df['datetime'] = datetime_series
    
#     return df
    
# data = convert_eventid_to_datetime(region_10_df)['datetime']

#plt.show()
# Out:
# Dropped 1 malformed event id rows.

# %%
# Line plot of events over time
# grouped_terr_df = terrorism_df.groupby(['datetime']).count()

datetime_df = terrorism_df.set_index('datetime')


# monthly_terr_df = terrorism_df.groupby([(terrorism_df.iyear),(terrorism_df.imonth)]).count()
start_date = '1970-01-01'
end_date = '2017-01-1'
# daily_terr_df = datetime_df[start_date:end_date].groupby(pd.Grouper(freq='D')).count()
monthly_terr_df = datetime_df[start_date:end_date].groupby(pd.Grouper(freq='M')).count()

# daily_terr_df['eventid'].plot(kind='line', figsize=[30,5])
monthly_terr_df['eventid'].plot(kind='line', figsize=[30,5])
# plt.savefig('./terr_event_date.png')
