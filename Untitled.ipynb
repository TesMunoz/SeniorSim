# %% [markdown]
# Use Pandas to clean up data

# %%
import pandas as pd
import numpy as np

#read in the data file: location, don't read column index, reading windows encoding, datatype, only specific columns
df = pd.read_csv('./inputs/globalterrorismdb_0617dist.csv',index_col=0, encoding='ISO-8859-1', dtype=object,  
                 usecols=['eventid', 'iyear', 'imonth', 'iday', 'country', 'region', 
                         'latitude', 'longitude', 'crit1', 'crit2', 'crit3', 'attacktype1','targtype1','targsubtype1','weaptype1',
                          'weapsubtype1']),

print(df)
# Out:
# (             iyear imonth iday country region    latitude    longitude crit1  \
# eventid
# 197000000001  1970      7    2      58      2   18.456792   -69.951164     1
# 197000000002  1970      0    0     130      1   19.432608   -99.133207     1
# 197001000001  1970      1    0     160      5   15.478598   120.599741     1
# 197001000002  1970      1    0      78      8   37.983773    23.728157     1
# 197001000003  1970      1    0     101      4   33.580412   130.396361     1
# 197001010002  1970      1    1     217      1   37.005105   -89.176269     1
# 197001020001  1970      1    2     218      3  -34.891151   -56.187214     1
# 197001020002  1970      1    2     217      1   37.805065  -122.273024     1
# 197001020003  1970      1    2     217      1   43.076592   -89.412488     1
# 197001030001  1970      1    3     217      1    43.07295   -89.386694     1
# 197001050001  1970      1    1     217      1     43.4685   -89.744299     1
# ...
